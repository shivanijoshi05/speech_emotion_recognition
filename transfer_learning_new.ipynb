# %% [markdown]
# <a href="https://colab.research.google.com/github/shivanijoshi05/speech_emotion_recognition/blob/main/transfer_learning_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import glob
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# IMPORT NECESSARY LIBRARIES
import numpy as np
import tensorflow as tf
#from tensorflow.python.keras.preprocessing.image import ImageDataGenerator, load_img
import pandas as pd
from sklearn.metrics import confusion_matrix
import sys
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import itertools
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
import warnings
# ignore warnings 
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
import keras
from keras import layers, models, Model, optimizers
from keras.models import Sequential, Model, model_from_json
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Dense, Embedding, LSTM
from keras.regularizers import l2
from keras.constraints import max_norm
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import shuffle
from tensorflow.python.keras import layers, models, Model, optimizers
from keras import regularizers
from keras import layers, models, Model, optimizers
from random import randint
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from matplotlib import pyplot
from tensorflow.keras.utils  import to_categorical
from keras.preprocessing.image import ImageDataGenerator, load_img

# %%
angry = glob.glob('/content/drive/MyDrive/speech_emotion_recognition/final/original/angry/*.*')
calm = glob.glob('/content/drive/MyDrive/speech_emotion_recognition/final/original/calm/*.*')
disgust = glob.glob('/content/drive/MyDrive/speech_emotion_recognition/final/original/disgust/*.*')
fearful = glob.glob('/content/drive/MyDrive/speech_emotion_recognition/final/original/fearful/*.*')
happy = glob.glob('/content/drive/MyDrive/speech_emotion_recognition/final/original/happy/*.*')
neutral = glob.glob('/content/drive/MyDrive/speech_emotion_recognition/final/original/neutral/*.*')
sad = glob.glob('/content/drive/MyDrive/speech_emotion_recognition/final/original/sad/*.*')
surprised = glob.glob('/content/drive/MyDrive/speech_emotion_recognition/final/original/surprised/*.*')

# %%
data = []
labels = []

for i in angry:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', target_size= (224,224))
    image=np.array(image)
    data.append(image)
    labels.append('Angry')
for i in calm:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', target_size= (224,224))
    image=np.array(image)
    data.append(image)
    labels.append('Calm')
for i in disgust:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', target_size= (224,224))
    image=np.array(image)
    data.append(image)
    labels.append('Disgust')
for i in fearful:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', target_size= (224,224))
    image=np.array(image)
    data.append(image)
    labels.append('Fearful')
for i in happy:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', target_size= (224,224))
    image=np.array(image)
    data.append(image)
    labels.append('Happy')
for i in neutral:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', target_size= (224,224))
    image=np.array(image)
    data.append(image)
    labels.append('Neutral')
for i in sad:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', target_size= (224,224))
    image=np.array(image)
    data.append(image)
    labels.append('Sad')
for i in surprised:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', target_size= (224,224))
    image=np.array(image)
    data.append(image)
    labels.append('Surprised')
data = np.array(data)
labels = np.array(labels)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labels, random_state=22, test_size=0.2, shuffle=True)

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# %%
lb = LabelEncoder()

y_train = to_categorical(lb.fit_transform(y_train))
y_test = to_categorical(lb.fit_transform(y_test))

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (1920, 224, 224, 3)
# (480, 224, 224, 3)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (1920, 8)
# (480, 8)

# %%
def get_classlabel(class_code):
    labels = {'Angry':'Angry', 'Calm':'Calm', 'Disgust':'Disgust', 'Fearful':'Fearful', 'Happy':'Happy', 'Neutral':'Neutral','Sad':'Sad','Surprised':'Surprised'}
    
    return labels[class_code]

f,ax = plt.subplots(5,5) 
f.subplots_adjust(0,0,3,3)
for i in range(0,5,1):
    for j in range(0,5,1):
        rnd_number = randint(0,len(data))
        ax[i,j].imshow(data[rnd_number])
        ax[i,j].set_title(get_classlabel(labels[rnd_number]))
        ax[i,j].axis('off')

# %% [markdown]
# # VGG16 Fine Tuning With Image Augmentation

# %%
#The goal of this image classification challenge is to train a model that can correctly classify an input image into 1,000 separate object categories.
from keras.applications.vgg16 import VGG16

vgg16_model = VGG16(weights='imagenet',include_top=False,input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step

# %%
for layer in vgg16_model.layers[:15]:
    layer.trainable = False

# %%
x = vgg16_model.output
x = Flatten()(x) # Flatten dimensions to for use in FC layers
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x) # Dropout layer to reduce overfitting
x = Dense(256, activation='relu')(x)
x = Dropout(0.01)(x)
x = Dense(8, activation='softmax')(x) # Softmax for multiclass
transfer_model = Model(inputs=vgg16_model.input, outputs=x)

# %%
for i, layer in enumerate(vgg16_model.layers):
    print(i, layer.name, layer.trainable)
# Out:
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool True

# %%
# reduce learning rate when val_accuracy has stopped improving
lr_reduce = ReduceLROnPlateau(monitor='val_accuracy', 
                              patience = 2, 
                              verbose=1,
                              factor=0.95, 
                              min_lr=0.000001)

checkpoint = ModelCheckpoint('vgg16_augment.h15', monitor= 'val_accuracy', mode= 'max', save_best_only = True, verbose= 1)

# %%
train_datagen = ImageDataGenerator(zoom_range=0.3,
                                   rotation_range=20,
                                   width_shift_range=0.15)

train_generator = train_datagen.flow(X_train,
                                     y_train,
                                     batch_size=1)

# %%
img_rows, img_cols = 224, 224

for x, y in train_datagen.flow(X_train, y_train, batch_size=9):
    # Show the first 9 images
    for i in range(0, 9):
        pyplot.subplot(330 + 1 + i)
        pyplot.imshow(x[i].reshape(img_rows, img_cols, 3))
    # show the plot
    pyplot.show()
    break

# %%
from keras import layers, models, Model, optimizers

learning_rate= 5e-5
transfer_model.compile(loss="categorical_crossentropy", optimizer=tf.optimizers.Adam(learning_rate), metrics=["accuracy"])

history = transfer_model.fit(train_generator,
                    validation_data=(X_test,y_test),
                    epochs=80,
                    callbacks=[lr_reduce,checkpoint])
# Out:
# Epoch 1/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 2.0189 - accuracy: 0.1897
# Epoch 1: val_accuracy improved from -inf to 0.23750, saving model to vgg16_augment.h15
# INFO:tensorflow:Assets written to: vgg16_augment.h15/assets
# 1920/1920 [==============================] - 114s 54ms/step - loss: 2.0180 - accuracy: 0.1901 - val_loss: 2.0250 - val_accuracy: 0.2375 - lr: 5.0000e-05
# Epoch 2/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 1.8004 - accuracy: 0.2835
# Epoch 2: val_accuracy improved from 0.23750 to 0.35625, saving model to vgg16_augment.h15
# INFO:tensorflow:Assets written to: vgg16_augment.h15/assets
# 1920/1920 [==============================] - 99s 52ms/step - loss: 1.8007 - accuracy: 0.2833 - val_loss: 1.7032 - val_accuracy: 0.3562 - lr: 5.0000e-05
# Epoch 3/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 1.6552 - accuracy: 0.3538
# Epoch 3: val_accuracy improved from 0.35625 to 0.42917, saving model to vgg16_augment.h15
# INFO:tensorflow:Assets written to: vgg16_augment.h15/assets
# 1920/1920 [==============================] - 98s 51ms/step - loss: 1.6545 - accuracy: 0.3542 - val_loss: 1.5039 - val_accuracy: 0.4292 - lr: 5.0000e-05
# Epoch 4/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 1.4923 - accuracy: 0.4372
# Epoch 4: val_accuracy did not improve from 0.42917
# 1920/1920 [==============================] - 94s 49ms/step - loss: 1.4924 - accuracy: 0.4370 - val_loss: 1.6178 - val_accuracy: 0.4125 - lr: 5.0000e-05
# Epoch 5/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 1.3548 - accuracy: 0.4883
# Epoch 5: val_accuracy improved from 0.42917 to 0.54792, saving model to vgg16_augment.h15
# INFO:tensorflow:Assets written to: vgg16_augment.h15/assets
# 1920/1920 [==============================] - 97s 51ms/step - loss: 1.3562 - accuracy: 0.4880 - val_loss: 1.1672 - val_accuracy: 0.5479 - lr: 5.0000e-05
# Epoch 6/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 1.2124 - accuracy: 0.5435
# Epoch 6: val_accuracy improved from 0.54792 to 0.56875, saving model to vgg16_augment.h15
# INFO:tensorflow:Assets written to: vgg16_augment.h15/assets
# 1920/1920 [==============================] - 98s 51ms/step - loss: 1.2128 - accuracy: 0.5432 - val_loss: 1.1690 - val_accuracy: 0.5688 - lr: 5.0000e-05
# Epoch 7/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 1.1285 - accuracy: 0.5789
# Epoch 7: val_accuracy improved from 0.56875 to 0.62083, saving model to vgg16_augment.h15
# INFO:tensorflow:Assets written to: vgg16_augment.h15/assets
# 1920/1920 [==============================] - 97s 51ms/step - loss: 1.1284 - accuracy: 0.5792 - val_loss: 0.9889 - val_accuracy: 0.6208 - lr: 5.0000e-05
# Epoch 8/80
# 1920/1920 [==============================] - ETA: 0s - loss: 1.0022 - accuracy: 0.6307
# Epoch 8: val_accuracy improved from 0.62083 to 0.63958, saving model to vgg16_augment.h15
# INFO:tensorflow:Assets written to: vgg16_augment.h15/assets
# 1920/1920 [==============================] - 98s 51ms/step - loss: 1.0022 - accuracy: 0.6307 - val_loss: 1.0233 - val_accuracy: 0.6396 - lr: 5.0000e-05
# Epoch 9/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.9367 - accuracy: 0.6411
# Epoch 9: val_accuracy did not improve from 0.63958
# 1920/1920 [==============================] - 94s 49ms/step - loss: 0.9367 - accuracy: 0.6411 - val_loss: 1.1519 - val_accuracy: 0.6187 - lr: 5.0000e-05
# Epoch 10/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.8231 - accuracy: 0.6953
# Epoch 10: val_accuracy improved from 0.63958 to 0.67917, saving model to vgg16_augment.h15
# INFO:tensorflow:Assets written to: vgg16_augment.h15/assets
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.8231 - accuracy: 0.6953 - val_loss: 1.0031 - val_accuracy: 0.6792 - lr: 5.0000e-05
# Epoch 11/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.7945 - accuracy: 0.7063
# Epoch 11: val_accuracy did not improve from 0.67917
# 1920/1920 [==============================] - 94s 49ms/step - loss: 0.7945 - accuracy: 0.7063 - val_loss: 1.0510 - val_accuracy: 0.6208 - lr: 5.0000e-05
# Epoch 12/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.7229 - accuracy: 0.7411
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.749999880004907e-05.
#
# Epoch 12: val_accuracy did not improve from 0.67917
# 1920/1920 [==============================] - 96s 50ms/step - loss: 0.7229 - accuracy: 0.7411 - val_loss: 1.1150 - val_accuracy: 0.6438 - lr: 5.0000e-05
# Epoch 13/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.6457 - accuracy: 0.7682
# Epoch 13: val_accuracy improved from 0.67917 to 0.71875, saving model to vgg16_augment.h15
# INFO:tensorflow:Assets written to: vgg16_augment.h15/assets
# 1920/1920 [==============================] - 99s 52ms/step - loss: 0.6457 - accuracy: 0.7682 - val_loss: 0.8664 - val_accuracy: 0.7188 - lr: 4.7500e-05
# Epoch 14/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.6086 - accuracy: 0.7879
# Epoch 14: val_accuracy did not improve from 0.71875
# 1920/1920 [==============================] - 96s 50ms/step - loss: 0.6084 - accuracy: 0.7880 - val_loss: 0.9663 - val_accuracy: 0.6833 - lr: 4.7500e-05
# Epoch 15/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.5751 - accuracy: 0.7869
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.512499799602665e-05.
#
# Epoch 15: val_accuracy did not improve from 0.71875
# 1920/1920 [==============================] - 95s 50ms/step - loss: 0.5748 - accuracy: 0.7870 - val_loss: 0.8988 - val_accuracy: 0.6833 - lr: 4.7500e-05
# Epoch 16/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.5755 - accuracy: 0.8025
# Epoch 16: val_accuracy did not improve from 0.71875
# 1920/1920 [==============================] - 96s 50ms/step - loss: 0.5752 - accuracy: 0.8026 - val_loss: 0.9840 - val_accuracy: 0.6958 - lr: 4.5125e-05
# Epoch 17/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.4997 - accuracy: 0.8254
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.286874809622532e-05.
#
# Epoch 17: val_accuracy did not improve from 0.71875
# 1920/1920 [==============================] - 96s 50ms/step - loss: 0.4995 - accuracy: 0.8255 - val_loss: 1.3245 - val_accuracy: 0.6792 - lr: 4.5125e-05
# Epoch 18/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.4634 - accuracy: 0.8396
# Epoch 18: val_accuracy improved from 0.71875 to 0.76667, saving model to vgg16_augment.h15
# INFO:tensorflow:Assets written to: vgg16_augment.h15/assets
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.4634 - accuracy: 0.8396 - val_loss: 0.7546 - val_accuracy: 0.7667 - lr: 4.2869e-05
# Epoch 19/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.4352 - accuracy: 0.8489
# Epoch 19: val_accuracy did not improve from 0.76667
# 1920/1920 [==============================] - 96s 50ms/step - loss: 0.4350 - accuracy: 0.8490 - val_loss: 0.7703 - val_accuracy: 0.7625 - lr: 4.2869e-05
# Epoch 20/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.3949 - accuracy: 0.8646
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.072531155543402e-05.
#
# Epoch 20: val_accuracy did not improve from 0.76667
# 1920/1920 [==============================] - 94s 49ms/step - loss: 0.3949 - accuracy: 0.8646 - val_loss: 0.9432 - val_accuracy: 0.7125 - lr: 4.2869e-05
# Epoch 21/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.3851 - accuracy: 0.8599
# Epoch 21: val_accuracy improved from 0.76667 to 0.77500, saving model to vgg16_augment.h15
# INFO:tensorflow:Assets written to: vgg16_augment.h15/assets
# 1920/1920 [==============================] - 99s 52ms/step - loss: 0.3851 - accuracy: 0.8599 - val_loss: 0.7633 - val_accuracy: 0.7750 - lr: 4.0725e-05
# Epoch 22/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.3430 - accuracy: 0.8801
# Epoch 22: val_accuracy did not improve from 0.77500
# 1920/1920 [==============================] - 96s 50ms/step - loss: 0.3428 - accuracy: 0.8802 - val_loss: 1.3687 - val_accuracy: 0.6854 - lr: 4.0725e-05
# Epoch 23/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.3559 - accuracy: 0.8813
# Epoch 23: ReduceLROnPlateau reducing learning rate to 3.868904459523037e-05.
#
# Epoch 23: val_accuracy did not improve from 0.77500
# 1920/1920 [==============================] - 94s 49ms/step - loss: 0.3559 - accuracy: 0.8813 - val_loss: 0.8028 - val_accuracy: 0.7604 - lr: 4.0725e-05
# Epoch 24/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.2747 - accuracy: 0.9067
# Epoch 24: val_accuracy did not improve from 0.77500
# 1920/1920 [==============================] - 95s 49ms/step - loss: 0.2747 - accuracy: 0.9068 - val_loss: 0.9699 - val_accuracy: 0.7604 - lr: 3.8689e-05
# Epoch 25/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.3397 - accuracy: 0.8839
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.6754593747900795e-05.
#
# Epoch 25: val_accuracy did not improve from 0.77500
# 1920/1920 [==============================] - 94s 49ms/step - loss: 0.3397 - accuracy: 0.8839 - val_loss: 1.1127 - val_accuracy: 0.7292 - lr: 3.8689e-05
# Epoch 26/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.2516 - accuracy: 0.9119
# Epoch 26: val_accuracy did not improve from 0.77500
# 1920/1920 [==============================] - 95s 50ms/step - loss: 0.2514 - accuracy: 0.9120 - val_loss: 1.0382 - val_accuracy: 0.7479 - lr: 3.6755e-05
# Epoch 27/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.2698 - accuracy: 0.9052
# Epoch 27: val_accuracy improved from 0.77500 to 0.80208, saving model to vgg16_augment.h15
# INFO:tensorflow:Assets written to: vgg16_augment.h15/assets
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.2697 - accuracy: 0.9052 - val_loss: 0.8682 - val_accuracy: 0.8021 - lr: 3.6755e-05
# Epoch 28/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.2629 - accuracy: 0.9167
# Epoch 28: val_accuracy did not improve from 0.80208
# 1920/1920 [==============================] - 95s 49ms/step - loss: 0.2629 - accuracy: 0.9167 - val_loss: 0.9452 - val_accuracy: 0.7667 - lr: 3.6755e-05
# Epoch 29/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.2637 - accuracy: 0.9026
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.491686475172173e-05.
#
# Epoch 29: val_accuracy did not improve from 0.80208
# 1920/1920 [==============================] - 95s 49ms/step - loss: 0.2637 - accuracy: 0.9026 - val_loss: 0.7483 - val_accuracy: 0.7875 - lr: 3.6755e-05
# Epoch 30/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.2299 - accuracy: 0.9208
# Epoch 30: val_accuracy did not improve from 0.80208
# 1920/1920 [==============================] - 95s 50ms/step - loss: 0.2298 - accuracy: 0.9208 - val_loss: 0.8153 - val_accuracy: 0.7646 - lr: 3.4917e-05
# Epoch 31/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.2108 - accuracy: 0.9224
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.3171022550959606e-05.
#
# Epoch 31: val_accuracy did not improve from 0.80208
# 1920/1920 [==============================] - 95s 49ms/step - loss: 0.2108 - accuracy: 0.9224 - val_loss: 0.8927 - val_accuracy: 0.7896 - lr: 3.4917e-05
# Epoch 32/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.1857 - accuracy: 0.9344
# Epoch 32: val_accuracy did not improve from 0.80208
# 1920/1920 [==============================] - 96s 50ms/step - loss: 0.1857 - accuracy: 0.9344 - val_loss: 0.9884 - val_accuracy: 0.7812 - lr: 3.3171e-05
# Epoch 33/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.2146 - accuracy: 0.9396
# Epoch 33: ReduceLROnPlateau reducing learning rate to 3.1512470559391656e-05.
#
# Epoch 33: val_accuracy did not improve from 0.80208
# 1920/1920 [==============================] - 96s 50ms/step - loss: 0.2146 - accuracy: 0.9396 - val_loss: 0.9061 - val_accuracy: 0.7688 - lr: 3.3171e-05
# Epoch 34/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.1730 - accuracy: 0.9396
# Epoch 34: val_accuracy did not improve from 0.80208
# 1920/1920 [==============================] - 96s 50ms/step - loss: 0.1729 - accuracy: 0.9396 - val_loss: 0.7619 - val_accuracy: 0.8000 - lr: 3.1512e-05
# Epoch 35/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.2114 - accuracy: 0.9354
# Epoch 35: ReduceLROnPlateau reducing learning rate to 2.9936847204226067e-05.
#
# Epoch 35: val_accuracy did not improve from 0.80208
# 1920/1920 [==============================] - 96s 50ms/step - loss: 0.2114 - accuracy: 0.9354 - val_loss: 1.0453 - val_accuracy: 0.7646 - lr: 3.1512e-05
# Epoch 36/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.1622 - accuracy: 0.9515
# Epoch 36: val_accuracy did not improve from 0.80208
# 1920/1920 [==============================] - 94s 49ms/step - loss: 0.1621 - accuracy: 0.9516 - val_loss: 1.0350 - val_accuracy: 0.7750 - lr: 2.9937e-05
# Epoch 37/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.1755 - accuracy: 0.9438
# Epoch 37: ReduceLROnPlateau reducing learning rate to 2.844000518962275e-05.
#
# Epoch 37: val_accuracy did not improve from 0.80208
# 1920/1920 [==============================] - 95s 50ms/step - loss: 0.1755 - accuracy: 0.9438 - val_loss: 0.8086 - val_accuracy: 0.7937 - lr: 2.9937e-05
# Epoch 38/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.1436 - accuracy: 0.9536
# Epoch 38: val_accuracy did not improve from 0.80208
# 1920/1920 [==============================] - 95s 50ms/step - loss: 0.1435 - accuracy: 0.9536 - val_loss: 0.8348 - val_accuracy: 0.8021 - lr: 2.8440e-05
# Epoch 39/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.1578 - accuracy: 0.9510
# Epoch 39: ReduceLROnPlateau reducing learning rate to 2.7018004584533627e-05.
#
# Epoch 39: val_accuracy did not improve from 0.80208
# 1920/1920 [==============================] - 95s 50ms/step - loss: 0.1577 - accuracy: 0.9510 - val_loss: 0.8349 - val_accuracy: 0.7958 - lr: 2.8440e-05
# Epoch 40/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.1342 - accuracy: 0.9599
# Epoch 40: val_accuracy did not improve from 0.80208
# 1920/1920 [==============================] - 94s 49ms/step - loss: 0.1342 - accuracy: 0.9599 - val_loss: 1.0140 - val_accuracy: 0.7833 - lr: 2.7018e-05
# Epoch 41/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.1508 - accuracy: 0.9526
# Epoch 41: ReduceLROnPlateau reducing learning rate to 2.5667104182502953e-05.
#
# Epoch 41: val_accuracy did not improve from 0.80208
# 1920/1920 [==============================] - 95s 49ms/step - loss: 0.1508 - accuracy: 0.9526 - val_loss: 0.9930 - val_accuracy: 0.8021 - lr: 2.7018e-05
# Epoch 42/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.9656
# Epoch 42: val_accuracy did not improve from 0.80208
# 1920/1920 [==============================] - 96s 50ms/step - loss: 0.1167 - accuracy: 0.9656 - val_loss: 0.9616 - val_accuracy: 0.8021 - lr: 2.5667e-05
# Epoch 43/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.1143 - accuracy: 0.9641
# Epoch 43: val_accuracy improved from 0.80208 to 0.81042, saving model to vgg16_augment.h15
# INFO:tensorflow:Assets written to: vgg16_augment.h15/assets
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.1143 - accuracy: 0.9641 - val_loss: 0.8672 - val_accuracy: 0.8104 - lr: 2.5667e-05
# Epoch 44/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.1203 - accuracy: 0.9609
# Epoch 44: val_accuracy did not improve from 0.81042
# 1920/1920 [==============================] - 95s 50ms/step - loss: 0.1203 - accuracy: 0.9609 - val_loss: 1.2588 - val_accuracy: 0.7854 - lr: 2.5667e-05
# Epoch 45/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.1329 - accuracy: 0.9615
# Epoch 45: ReduceLROnPlateau reducing learning rate to 2.438374940538779e-05.
#
# Epoch 45: val_accuracy did not improve from 0.81042
# 1920/1920 [==============================] - 95s 50ms/step - loss: 0.1329 - accuracy: 0.9615 - val_loss: 0.8332 - val_accuracy: 0.7896 - lr: 2.5667e-05
# Epoch 46/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9672
# Epoch 46: val_accuracy did not improve from 0.81042
# 1920/1920 [==============================] - 94s 49ms/step - loss: 0.1037 - accuracy: 0.9672 - val_loss: 1.1057 - val_accuracy: 0.7771 - lr: 2.4384e-05
# Epoch 47/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0712 - accuracy: 0.9745
# Epoch 47: ReduceLROnPlateau reducing learning rate to 2.31645619351184e-05.
#
# Epoch 47: val_accuracy did not improve from 0.81042
# 1920/1920 [==============================] - 97s 50ms/step - loss: 0.0712 - accuracy: 0.9745 - val_loss: 1.2671 - val_accuracy: 0.7875 - lr: 2.4384e-05
# Epoch 48/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 0.9635
# Epoch 48: val_accuracy did not improve from 0.81042
# 1920/1920 [==============================] - 97s 50ms/step - loss: 0.1358 - accuracy: 0.9635 - val_loss: 1.0678 - val_accuracy: 0.7729 - lr: 2.3165e-05
# Epoch 49/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0748 - accuracy: 0.9766
# Epoch 49: ReduceLROnPlateau reducing learning rate to 2.2006334529578452e-05.
#
# Epoch 49: val_accuracy did not improve from 0.81042
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.0748 - accuracy: 0.9766 - val_loss: 1.3478 - val_accuracy: 0.8062 - lr: 2.3165e-05
# Epoch 50/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.1095 - accuracy: 0.9682
# Epoch 50: val_accuracy did not improve from 0.81042
# 1920/1920 [==============================] - 97s 50ms/step - loss: 0.1094 - accuracy: 0.9682 - val_loss: 1.0540 - val_accuracy: 0.8000 - lr: 2.2006e-05
# Epoch 51/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0769 - accuracy: 0.9755
# Epoch 51: ReduceLROnPlateau reducing learning rate to 2.0906017198285554e-05.
#
# Epoch 51: val_accuracy did not improve from 0.81042
# 1920/1920 [==============================] - 97s 50ms/step - loss: 0.0769 - accuracy: 0.9755 - val_loss: 1.0825 - val_accuracy: 0.8000 - lr: 2.2006e-05
# Epoch 52/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0834 - accuracy: 0.9745
# Epoch 52: val_accuracy did not improve from 0.81042
# 1920/1920 [==============================] - 96s 50ms/step - loss: 0.0834 - accuracy: 0.9745 - val_loss: 1.0714 - val_accuracy: 0.8104 - lr: 2.0906e-05
# Epoch 53/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.9750
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.9860715474351307e-05.
#
# Epoch 53: val_accuracy did not improve from 0.81042
# 1920/1920 [==============================] - 97s 51ms/step - loss: 0.0785 - accuracy: 0.9750 - val_loss: 1.2841 - val_accuracy: 0.7979 - lr: 2.0906e-05
# Epoch 54/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0711 - accuracy: 0.9760
# Epoch 54: val_accuracy did not improve from 0.81042
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.0711 - accuracy: 0.9760 - val_loss: 1.4444 - val_accuracy: 0.7896 - lr: 1.9861e-05
# Epoch 55/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9776
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1.886768004624173e-05.
#
# Epoch 55: val_accuracy did not improve from 0.81042
# 1920/1920 [==============================] - 97s 50ms/step - loss: 0.0744 - accuracy: 0.9776 - val_loss: 1.0457 - val_accuracy: 0.7979 - lr: 1.9861e-05
# Epoch 56/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0837 - accuracy: 0.9760
# Epoch 56: val_accuracy did not improve from 0.81042
# 1920/1920 [==============================] - 99s 51ms/step - loss: 0.0837 - accuracy: 0.9760 - val_loss: 1.4930 - val_accuracy: 0.8000 - lr: 1.8868e-05
# Epoch 57/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0706 - accuracy: 0.9760
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1.792429638953763e-05.
#
# Epoch 57: val_accuracy did not improve from 0.81042
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.0706 - accuracy: 0.9760 - val_loss: 1.7270 - val_accuracy: 0.7771 - lr: 1.8868e-05
# Epoch 58/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0632 - accuracy: 0.9802
# Epoch 58: val_accuracy improved from 0.81042 to 0.82500, saving model to vgg16_augment.h15
# INFO:tensorflow:Assets written to: vgg16_augment.h15/assets
# 1920/1920 [==============================] - 102s 53ms/step - loss: 0.0631 - accuracy: 0.9802 - val_loss: 1.0684 - val_accuracy: 0.8250 - lr: 1.7924e-05
# Epoch 59/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0584 - accuracy: 0.9823
# Epoch 59: val_accuracy did not improve from 0.82500
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.0584 - accuracy: 0.9823 - val_loss: 1.2037 - val_accuracy: 0.8104 - lr: 1.7924e-05
# Epoch 60/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0663 - accuracy: 0.9818
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.7028081310854758e-05.
#
# Epoch 60: val_accuracy did not improve from 0.82500
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.0663 - accuracy: 0.9818 - val_loss: 1.0843 - val_accuracy: 0.8229 - lr: 1.7924e-05
# Epoch 61/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9828
# Epoch 61: val_accuracy did not improve from 0.82500
# 1920/1920 [==============================] - 100s 52ms/step - loss: 0.0704 - accuracy: 0.9828 - val_loss: 1.1938 - val_accuracy: 0.8229 - lr: 1.7028e-05
# Epoch 62/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0751 - accuracy: 0.9812
# Epoch 62: val_accuracy improved from 0.82500 to 0.82917, saving model to vgg16_augment.h15
# INFO:tensorflow:Assets written to: vgg16_augment.h15/assets
# 1920/1920 [==============================] - 105s 55ms/step - loss: 0.0751 - accuracy: 0.9812 - val_loss: 0.9787 - val_accuracy: 0.8292 - lr: 1.7028e-05
# Epoch 63/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0630 - accuracy: 0.9838
# Epoch 63: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 101s 53ms/step - loss: 0.0630 - accuracy: 0.9839 - val_loss: 0.9112 - val_accuracy: 0.8104 - lr: 1.7028e-05
# Epoch 64/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0386 - accuracy: 0.9865
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.6176677763724002e-05.
#
# Epoch 64: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 102s 53ms/step - loss: 0.0386 - accuracy: 0.9865 - val_loss: 1.2667 - val_accuracy: 0.8000 - lr: 1.7028e-05
# Epoch 65/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9917
# Epoch 65: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 101s 53ms/step - loss: 0.0404 - accuracy: 0.9917 - val_loss: 1.3024 - val_accuracy: 0.8104 - lr: 1.6177e-05
# Epoch 66/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0804 - accuracy: 0.9792
# Epoch 66: ReduceLROnPlateau reducing learning rate to 1.5367844480351777e-05.
#
# Epoch 66: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 101s 53ms/step - loss: 0.0804 - accuracy: 0.9792 - val_loss: 1.1465 - val_accuracy: 0.8167 - lr: 1.6177e-05
# Epoch 67/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0538 - accuracy: 0.9849
# Epoch 67: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 99s 51ms/step - loss: 0.0538 - accuracy: 0.9849 - val_loss: 1.3235 - val_accuracy: 0.8042 - lr: 1.5368e-05
# Epoch 68/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0714 - accuracy: 0.9849
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.4599452515540178e-05.
#
# Epoch 68: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.0714 - accuracy: 0.9849 - val_loss: 1.2770 - val_accuracy: 0.7896 - lr: 1.5368e-05
# Epoch 69/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0495 - accuracy: 0.9812
# Epoch 69: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.0495 - accuracy: 0.9812 - val_loss: 1.2586 - val_accuracy: 0.7854 - lr: 1.4599e-05
# Epoch 70/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0373 - accuracy: 0.9901
# Epoch 70: ReduceLROnPlateau reducing learning rate to 1.3869480062567163e-05.
#
# Epoch 70: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 99s 52ms/step - loss: 0.0374 - accuracy: 0.9901 - val_loss: 1.2159 - val_accuracy: 0.8083 - lr: 1.4599e-05
# Epoch 71/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9875
# Epoch 71: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 99s 51ms/step - loss: 0.0406 - accuracy: 0.9875 - val_loss: 1.2937 - val_accuracy: 0.8146 - lr: 1.3869e-05
# Epoch 72/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0319 - accuracy: 0.9911
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1.3176006405046792e-05.
#
# Epoch 72: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.0319 - accuracy: 0.9911 - val_loss: 1.6231 - val_accuracy: 0.7958 - lr: 1.3869e-05
# Epoch 73/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0365 - accuracy: 0.9891
# Epoch 73: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.0365 - accuracy: 0.9891 - val_loss: 1.6224 - val_accuracy: 0.8188 - lr: 1.3176e-05
# Epoch 74/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0480 - accuracy: 0.9891
# Epoch 74: ReduceLROnPlateau reducing learning rate to 1.251720586878946e-05.
#
# Epoch 74: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 97s 51ms/step - loss: 0.0480 - accuracy: 0.9891 - val_loss: 1.7324 - val_accuracy: 0.7833 - lr: 1.3176e-05
# Epoch 75/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0513 - accuracy: 0.9839
# Epoch 75: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.0513 - accuracy: 0.9839 - val_loss: 1.5055 - val_accuracy: 0.8083 - lr: 1.2517e-05
# Epoch 76/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0294 - accuracy: 0.9922
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1.1891345229742e-05.
#
# Epoch 76: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.0294 - accuracy: 0.9922 - val_loss: 1.5000 - val_accuracy: 0.8146 - lr: 1.2517e-05
# Epoch 77/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0208 - accuracy: 0.9937
# Epoch 77: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.0208 - accuracy: 0.9937 - val_loss: 1.5685 - val_accuracy: 0.8021 - lr: 1.1891e-05
# Epoch 78/80
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0391 - accuracy: 0.9875
# Epoch 78: ReduceLROnPlateau reducing learning rate to 1.1296777665847911e-05.
#
# Epoch 78: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 98s 51ms/step - loss: 0.0391 - accuracy: 0.9875 - val_loss: 1.4721 - val_accuracy: 0.7937 - lr: 1.1891e-05
# Epoch 79/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9922
# Epoch 79: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 99s 51ms/step - loss: 0.0282 - accuracy: 0.9922 - val_loss: 1.5077 - val_accuracy: 0.8062 - lr: 1.1297e-05
# Epoch 80/80
# 1920/1920 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.9906
# Epoch 80: ReduceLROnPlateau reducing learning rate to 1.073193843694753e-05.
#
# Epoch 80: val_accuracy did not improve from 0.82917
# 1920/1920 [==============================] - 99s 52ms/step - loss: 0.0321 - accuracy: 0.9906 - val_loss: 1.7650 - val_accuracy: 0.8146 - lr: 1.1297e-05

# %%
path = 'drive/MyDrive/speech_emotion_recognition/models/'
transfer_model.save_weights(path +'vgg16_weights2.h5')
transfer_model.save(path + 'vgg16_model2.h5')

# %%
path = 'drive/MyDrive/speech_emotion_recognition/models/'
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig(path + 'vgg16_Model_Accuracy.png')
plt.show()

# %%
path = 'drive/MyDrive/speech_emotion_recognition/models/'

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig(path + 'vgg16_Model_Loss.png')
plt.show()

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize = (5,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
y_pred = transfer_model.predict(X_test)
Y_pred_classes = np.argmax(y_pred,axis=1) 
Y_true = np.argmax(y_test,axis=1)
dict_characters = {0: 'angry', 1: 'calm', 2: 'disgust', 3: 'fearful', 4: 'happy', 5: 'neutral', 6: 'sad', 7: 'surprised'}
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
plot_confusion_matrix(confusion_mtx, classes = list(dict_characters.values())) 
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_true, Y_pred_classes, target_names = ['angry','calm','disgust','fearful','happy','neutral','sad','surprised']))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.86      0.79      0.83        72
#         calm       0.88      0.81      0.84        57
#      disgust       0.82      0.84      0.83        69
#      fearful       0.96      0.72      0.82        65
#        happy       0.78      0.78      0.78        59
#      neutral       0.90      0.81      0.85        32
#          sad       0.61      0.88      0.72        68
#    surprised       0.91      0.88      0.89        58
#
#     accuracy                           0.81       480
#    macro avg       0.84      0.81      0.82       480
# weighted avg       0.83      0.81      0.82       480

# %% [markdown]
# # VGG19 Fine Tuning + Augmentation

# %%
from keras.applications import vgg19
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg19 import preprocess_input
from keras.applications.vgg19 import decode_predictions
from keras.applications.vgg19 import VGG19

vgg19_model = vgg19.VGG19(weights='imagenet', pooling='avg', include_top=False, input_shape = (224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step

# %%
#Image Data Augmentation
train_datagen = ImageDataGenerator(
                                    zoom_range=0.5,
                                   rotation_range=20,
                                   width_shift_range=0.5)

train_generator = train_datagen.flow(X_train,
                                     y_train,
                                     batch_size=16)

lr_reduce = ReduceLROnPlateau(monitor='val_acc', 
                              patience = 2, 
                              verbose=1,
                              factor=0.95, 
                              min_lr=0.000001)

checkpoint = ModelCheckpoint("vgg19.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
img_rows, img_cols = 224, 224

for x, y in train_datagen.flow(X_train, y_train, batch_size=9):
    # Show the first 9 images
    for i in range(0, 9):
        pyplot.subplot(330 + 1 + i)
        pyplot.imshow(x[i].reshape(img_rows, img_cols, 3))
    # show the plot
    pyplot.show()
    break

# %%
for layer in vgg19_model.layers[:12]:
    layer.trainable = False

# %%
for i, layer in enumerate(vgg19_model.layers):
    print(i, layer.name, layer.trainable)
# Out:
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_conv4 False
# 11 block3_pool False
# 12 block4_conv1 True
# 13 block4_conv2 True
# 14 block4_conv3 True
# 15 block4_conv4 True
# 16 block4_pool True
# 17 block5_conv1 True
# 18 block5_conv2 True
# 19 block5_conv3 True
# 20 block5_conv4 True
# 21 block5_pool True
# 22 global_average_pooling2d True

# %%
input_shape=(224,224,3)

model=models.Sequential()
model.add(vgg19_model)
model.add(Dense(256,activation='relu'))
model.add(Dropout(0.01))
model.add(Dense(8,activation='softmax'))
model.summary()

#Initializing the hyperparameters
learning_rate = 5e-5
model.compile(loss="categorical_crossentropy", optimizer=tf.optimizers.Adam(learning_rate), metrics = ['acc'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 512)               20024384
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 8)                 2056
#
# =================================================================
# Total params: 20,157,768
# Trainable params: 17,832,200
# Non-trainable params: 2,325,568
# _________________________________________________________________

# %%
epochs = 70
history = model.fit(train_generator,
                              epochs = epochs,  
                              validation_data = (X_test,y_test), 
                              callbacks=[checkpoint,lr_reduce], 
                              verbose = 1
                              )
# Out:
# Epoch 1/70
#   3/120 [..............................] - ETA: 40:32 - loss: 2.0734 - acc: 0.1042
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-4170ccaa40a6> in <module>()
#       4                               validation_data = (X_test,y_test),
#       5                               callbacks=[checkpoint,lr_reduce],
# ----> 6                               verbose = 1
#       7                               )
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
path = 'drive/MyDrive/speech_emotion_recognition/models/'
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

plt.savefig(path + 'VGG19_Augmented_Model_Accuracy.png')
plt.show()

# %%
path = 'drive/MyDrive/speech_emotion_recognition/models/'

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig(path + 'VGG19_Augmented_Model_Loss.png')
plt.show()

# %%
y_pred = model.predict(X_test)
Y_pred_classes = np.argmax(y_pred,axis=1) 
Y_true = np.argmax(y_test,axis=1)
dict_characters = {0: 'angry', 1: 'calm', 2: 'disgust', 3: 'fearful', 4: 'happy', 5: 'neutral', 6: 'sad', 7: 'surprised'}
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
plot_confusion_matrix(confusion_mtx, classes = list(dict_characters.values())) 
plt.show()

# %%
print(classification_report(Y_true, Y_pred_classes, target_names = ['angry','calm','disgust','fearful','happy','neutral','sad','surprised']))

# %%
path = 'drive/MyDrive/speech_emotion_recognition/models/'
transfer_model.save_weights(path + 'vgg19_weights2.h5')
transfer_model.save(path + 'vgg19_model2.h5')
